# %% [markdown]
# # Module 6: Policy Simulation & Economics
# Run multiple transition scenarios and calculate NPV/LCOE.

# %%
import sys
import os
sys.path.insert(0, os.path.abspath('..'))

# %%
from src.simulation.policy_simulator import PolicySimulator
from src.simulation.economic_analysis import EconomicAnalyser

# %%
sim = PolicySimulator()
results = sim.run_all_scenarios()
results.head()

# %%
econ = EconomicAnalyser()
summary = econ.analyse(results)
summary

# %%
from IPython.display import Image
display(Image('../reports/simulation/payback_period.png'))
display(Image('../reports/simulation/sensitivity_tornado.png'))
