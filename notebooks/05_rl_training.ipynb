# %% [markdown]
# # Module 5: Reinforcement Learning Optimizer
# Train the PPO agent on the custom Microgrid Gymnasium environment.

# %%
import sys
import os
sys.path.insert(0, os.path.abspath('..'))

# %%
from src.models.rl_optimizer import RLLoadOptimizer

# %%
rl = RLLoadOptimizer()
rl.train()

# %%
metrics = rl.evaluate(n_episodes=2)
print('Evaluation metrics over 2 episodes:', metrics)
