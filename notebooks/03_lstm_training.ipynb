# %% [markdown]
# # Module 4: LSTM Model Training (Solar & Wind)
# Training the 2-layer LSTM model for forecasting.

# %%
import sys
import os
sys.path.insert(0, os.path.abspath('..'))

# %%
from src.models.lstm_forecaster import LSTMForecaster

# %%
# Train Solar LSTM
lstm_solar = LSTMForecaster(target='solar')
lstm_solar.train()

# %%
# Evaluate Solar LSTM
metrics_solar = lstm_solar.evaluate()
print('Metrics:', metrics_solar)

# %%
from IPython.display import Image
Image('../reports/lstm_solar_eval.png')
