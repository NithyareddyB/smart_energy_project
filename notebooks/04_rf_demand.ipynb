# %% [markdown]
# # Module 4: Random Forest Demand Prediction
# Train a Random Forest to predict grid demand.

# %%
import sys
import os
sys.path.insert(0, os.path.abspath('..'))

# %%
from src.models.rf_demand import RFDemandPredictor

# %%
rf = RFDemandPredictor()
rf.train(grid_search=False) # set to True for hyperparameter sweep

# %%
metrics = rf.evaluate()
print('Metrics:', metrics)

# %%
from IPython.display import Image
Image('../reports/rf_demand_eval.png')
Image('../reports/rf_feature_importance.png')
